# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# # Reads 'Youtube04-Eminem.csv' file  
# df = pd.read_csv(r"Youtube04-Eminem.csv", encoding ="latin-1") 
  
# comment_words = '' 
stopwords = set(STOPWORDS) 
  
# # iterate through the csv file 
# for val in df.CONTENT: 
      
#     # typecaste each val to string 
#     val = str(val) 
  
#     # split the value 
#     tokens = val.split() 
      
#     # Converts each token into lowercase 
#     for i in range(len(tokens)): 
#         tokens[i] = tokens[i].lower() 
      
#     comment_words += " ".join(tokens)+" "
  
neg_words = ['dirty', 'worst', 'poor', 'rude', 'terrible', 'never', 'told',
       'old', 'even', 'horrible', 'awful', 'tiny', 'filthy', 'disgusting',
       'positive', 'picture', 'wall', 'bad', 'avoid', 'management',
       'ever', 'broken', 'disappointing', 'joke', 'uncomfortable',
       'unfriendly', 'money', 'paid', 'unhelpful', 'loud', 'worse',
       'dark', 'bug', 'disappointed', 'noisy', 'poorly', 'elsewhere',
       'pay', 'motel', 'run', 'charged', 'barely', 'manager', 'smell',
       'better', 'overpriced', 'cheap', 'said', 'cockroach', 'sheet',
       'refund', 'carpet', 'mold', 'another', 'shabby', 'somewhere',
       'charge', 'night', 'work', 'roach', 'nothing', 'anyone', 'smelled',
       'customer', 'outdated', 'dingy', 'refused', 'stain', 'room',
       'sleep', 'call', 'mistake', 'toilet', 'unless', 'asked', 'dated',
       'website', 'credit', 'supposed', 'least', 'hilton', 'like',
       'recommend', 'booked', 'let', 'clearly', 'waste', 'attitude',
       'disappointment', 'furniture', 'hotel', 'experience', 'paper',
       'stained', 'else', 'ruined', 'shame', 'closed', 'tried',
       'unacceptable'] 

comment_words = " ".join(neg_words)

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show() 
# plt.savefig('../images/wordcloud_negative')
# Out:
# (-0.5, 799.5, 799.5, -0.5)

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# # Reads 'Youtube04-Eminem.csv' file  
# df = pd.read_csv(r"Youtube04-Eminem.csv", encoding ="latin-1") 
  
# comment_words = '' 
stopwords = set(STOPWORDS) 
  
# # iterate through the csv file 
# for val in df.CONTENT: 
      
#     # typecaste each val to string 
#     val = str(val) 
  
#     # split the value 
#     tokens = val.split() 
      
#     # Converts each token into lowercase 
#     for i in range(len(tokens)): 
#         tokens[i] = tokens[i].lower() 
      
#     comment_words += " ".join(tokens)+" "
  
neut_words = ['average', 'ok', 'location', 'however', 'okay', 'fine', 'basic',
       'dated', 'probably', 'small', 'decent', 'tired', 'pretty',
       'overall', 'bit', 'quite', 'good', 'seemed', 'need', 'though',
       'typical', 'updating', 'think', 'unfortunately', 'adequate',
       'tiny', 'busy', 'seems', 'limited', 'clean', 'room', 'nothing',
       'pro', 'disappointing', 'biggest', 'otherwise', 'guess', 'older',
       'little', 'rather', 'expected', 'purpose', 'price', 'fairly',
       'nice', 'annoying', 'crowded', 'mixed', 'impersonal', 'likely',
       'difficult', 'outdated', 'perhaps', 'worn', 'friendly', 'lacking',
       'lobby', 'bathroom', 'special', 'budget', 'maybe', 'frill',
       'tourist', 'bad', 'disappointed', 'distance', 'wear', 'expecting',
       'ordinary', 'fair', 'particularly', 'interesting', 'overly',
       'fancy', 'mind', 'served', 'carpet', 'people', 'update', 'looking',
       'located', 'somewhat', 'expect', 'lack', 'paid', 'tlc', 'sadly',
       'almost', 'elevator', 'issue', 'housekeeping', 'conference',
       'convenient', 'per', 'relatively', 'convention', 'pool',
       'improvement', 'improve', 'central'] 

comment_words = " ".join(neut_words)

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show() 
plt.savefig('../images/wordcloud_neutral')
# Out:
# (-0.5, 799.5, 799.5, -0.5)

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# # Reads 'Youtube04-Eminem.csv' file  
# df = pd.read_csv(r"Youtube04-Eminem.csv", encoding ="latin-1") 
  
# comment_words = '' 
stopwords = set(STOPWORDS) 
  
# # iterate through the csv file 
# for val in df.CONTENT: 
      
#     # typecaste each val to string 
#     val = str(val) 
  
#     # split the value 
#     tokens = val.split() 
      
#     # Converts each token into lowercase 
#     for i in range(len(tokens)): 
#         tokens[i] = tokens[i].lower() 
      
#     comment_words += " ".join(tokens)+" "
  
pos_words = ['great', 'perfect', 'excellent', 'comfortable', 'amazing', 'loved',
       'definitely', 'wonderful', 'helpful', 'highly', 'enjoyed',
       'fantastic', 'spacious', 'clean', 'quiet', 'everything', 'nice',
       'friendly', 'thank', 'tokyo', 'always', 'modern', 'awesome',
       'well', 'best', 'easy', 'thanks', 'beautiful', 'subway', 'happy',
       'lovely', 'view', 'large', 'nyc', 'love', 'recommend', 'stay',
       'outstanding', 'square', 'free', 'exceptional', 'plenty',
       'everyone', 'comfy', 'superb', 'appointed', 'professional',
       'delicious', 'accommodating', 'pleased', 'station', 'home',
       'right', 'helped', 'efficient', 'spotless', 'little', 'every',
       'fabulous', 'restaurant', 'bit', 'convenient', 'walk', 'th',
       'city', 'visit', 'beach', 'appreciated', 'within', 'greeted',
       'block', 'notch', 'minor', 'complaint', 'incredible', 'back',
       'return', 'liked', 'pleasure', 'attentive', 'downside', 'favorite',
       'wine', 'spectacular', 'super', 'cozy', 'waikiki', 'fresh', 'fun',
       'courteous', 'fast', 'japanese', 'upgraded', 'negative', 'size',
       'shinjuku', 'beat', 'quick', 'good', 'perfectly']

comment_words = " ".join(pos_words)

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show() 
# plt.savefig('../images/wordcloud_positive')
# Out:
# (-0.5, 799.5, 799.5, -0.5)
